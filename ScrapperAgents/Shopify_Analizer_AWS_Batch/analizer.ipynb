# %%
from langchain.document_loaders import SeleniumURLLoader
import tiktoken

from langchain.chat_models import ChatOpenAI
from langchain.chains.mapreduce import MapReduceChain
from langchain.text_splitter import CharacterTextSplitter
from langchain.chains import ReduceDocumentsChain, MapReduceDocumentsChain
from langchain import PromptTemplate, OpenAI, LLMChain

from langchain.prompts.chat import (
    ChatPromptTemplate,
    SystemMessagePromptTemplate,
    HumanMessagePromptTemplate,
)

import pandas as pd
import os
from dotenv import load_dotenv
import boto3
import io
import tempfile

# %%
load_dotenv()
openai_api_key = os.getenv("OPENAI_API_KEY")
aws_access_key_id = os.environ['AWS_ACCESS_KEY_ID']
aws_secret_access_key = os.environ['AWS_SECRET_ACCESS_KEY']
#aws_session_token = os.environ.get('AWS_SESSION_TOKEN')
sts_client = boto3.client('sts')
#brwoserless_api_key = os.getenv("BROWSERLESS_API_KEY")
#serper_api_key = os.getenv("SERP_API_KEY")

# %%
#variables

import argparse

# Create an argument parser
parser = argparse.ArgumentParser(description='My Script Description')

# Define command-line arguments
parser.add_argument('--input-folder', required=True, help='Path to the input file')
parser.add_argument('--input-file', required=True, help='Path to the output file')

args = parser.parse_args()


input_folder = args.input_folder
input_file = args.input_file
# Out:
# usage: ipykernel_launcher.py [-h] --input-folder INPUT_FOLDER --input-file INPUT_FILE
# ipykernel_launcher.py: error: the following arguments are required: --input-folder, --input-file
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# C:\Users\Usuario\miniconda3\envs\openai\Lib\site-packages\IPython\core\interactiveshell.py:3534: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
def html_loader(urls):
    loader = SeleniumURLLoader(urls=urls)
    data = loader.load()
    return data

def read_excel_s3(bucket_name,key):
    s3 = boto3.client('s3', aws_access_key_id=aws_access_key_id, aws_secret_access_key=aws_secret_access_key)
    
    # Specify the S3 bucket name
    s3_bucket_name = bucket_name
    
    
    s3_key = key
    
    # 'https://mini-excels.s3.eu-west-1.amazonaws.com/mini_excels/mini_excelsoutput_1.xlsx'
    
    # Read the Excel file from S3
    s3_response = s3.get_object(Bucket=s3_bucket_name, Key=s3_key)
    excel_data = s3_response['Body'].read()
    
    # You can now parse 'excel_data' using a library like pandas.
    return pd.read_excel(excel_data)

def output_writer(df,nombre):
    data = df
    file_name = nombre
        
    with tempfile.NamedTemporaryFile(suffix='.xlsx', delete=False) as temp_excel_file:
        data.to_excel(temp_excel_file.name, index=False, engine='xlsxwriter')
    
    # Read the temporary file into a binary stream
    with open(temp_excel_file.name, 'rb') as temp_file:
        excel_bytes = io.BytesIO(temp_file.read())
    
    # Specify the S3 key (file path) for the output file
    s3_key = f'output/{file_name}'  # You can customize the path as needed
    
    # Upload the Excel data to S3
    s3.put_object(Bucket=s3_bucket_name, Key=s3_key, Body=excel_bytes)
    
    print(f'Uploaded {file_name} to S3 at s3://{s3_bucket_name}/{s3_key}')

def summarizer(html_texto):
    llm = ChatOpenAI(model_name="gpt-3.5-turbo-16k", temperature=0)
    
    # Map
    map_template = """Aqui tienes el texto del home page de una tienda de ecommerce
    {docs}
    Haz un extenso resumen que caracterize el nicho de la tienda y los puntos importantes a destacar
    """
    map_prompt = PromptTemplate.from_template(map_template)
    map_chain = LLMChain(llm=llm, prompt=map_prompt)
    summary = map_chain.run(html_texto)
    return summary
    
def nicho_finder(resumen):
    template = """Pregunta: Cual es el nicho de esta tienda online segun el siguiente resúmen del home page:
    
    {resumen}
    
    La respuesta debe resumir el nicho en menos de 5 palabras. Responde única y exclusivamente con el nicho de la tienda, nada mas.
    """
    
    prompt = PromptTemplate(template=template, input_variables=["resumen"])
    
    llm = ChatOpenAI(model_name='gpt-3.5-turbo',temperature=0)
    
    #llm = OpenAI(openai_api_key="YOUR_API_KEY", openai_organization="YOUR_ORGANIZATION_ID")
    
    llm_chain = LLMChain(prompt=prompt, llm=llm)
    
    return llm_chain.run(resumen)
    
def advisor(query,summary):
    
    chat = ChatOpenAI(model_name="gpt-4", temperature=0)

    # Template to use for the system message prompt

    template = f"""Transformate en Roger de RojantMedia, un consultor experto en escalar la facturación de tiendas online.
    
            El cliente quiere facturar lo antes posible 20.000€ más al mes, cual es el camino más rápido? que recomendaciones le das personalizadas para su nicho y lo más especificas posibles, usando la información que te he pasado de su tienda online.

            Escribe UNICAMENTE las sugerencias más importantes y nada más.

            Humaniza tu lenguaje, de manera directa y divertida, pero sobretodo que él sienta que le estas dando claves de mucho valor para que quiera implementarlas ya.

            Usa solo los 3 puntos más importantes y estructuralos en (que está haciendo mal y porque eso le impide facturar más, y cual es la solución y que logrará, además acaba aportando datos que demuestren tangiblemente que tienes razón)

            Supon que el cliente ha probado antes a hacer publicidad y no le ha funcionado, esta quemado con este tema... explicale también porque le habrá ido mal

            Supon que el cliente quiere mejorar el valor percibido de su producto para mi cliente potencial y no se cómo venderlos logica y emocionalmente cómo haría un copywritter.
            ----
            INFORMACION TIENDA ONLINE: 

            {summary}

            ----
            
            """

    system_message_prompt = SystemMessagePromptTemplate.from_template(template)

    # Human question prompt
    human_template = "Responde la siguiente pregunta: {question}"
    human_message_prompt = HumanMessagePromptTemplate.from_template(human_template)

    chat_prompt = ChatPromptTemplate.from_messages(
        [system_message_prompt, human_message_prompt]
    )

    chain = LLMChain(llm=chat, prompt=chat_prompt)

    response_0 = chain.run(question=query,summary=summary)

    return response_0

# %%
df = read_excel_s3('mini-excels','mini_excels/mini_excelsoutput_1.xlsx')
df
#urls = list(df['domain'][:100])
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_6260\4154178291.py:22: FutureWarning: Passing bytes to 'read_excel' is deprecated and will be removed in a future version. To read from a byte string, wrap it in a `BytesIO` object.
#   return pd.read_excel(excel_data)
#                            domain country_code    created  \
# 0  www.visionnocturnaytermica.com       España 2023-05-19
# 1           www.gepcoformacion.es       España 2023-04-14
# 2                 mrribsmadrid.es       España 2023-05-19
# 3                         lewu.es       España 2023-04-07
# 4    www.powerbuildingoficial.com       España 2023-04-14
# 5                  electrotodo.fr       España 2023-04-07
# 6                   www.harven.es       España 2023-04-28
# 7     www.falconsdevilafranca.cat       España 2023-03-24
# 8               www.destockage.es       España 2023-06-02
# 9    www.reciclajesdelsurbahia.es       España 2023-04-21
#
#                              emails                   instagram  \
# 0   shop@visionnocturnaytermica.com   vision_nocturna_y_termica
# 1       info@gestionemergencias.com             gepco_formacion
# 2              info@mrribsmadrid.es              mr_ribs_madrid
# 3                      info@lewu.es     lewulearnandenjoywithus
# 4  soporte@powerbuildingoficial.com       powerbuilding_oficial
# 5           boutique@electrotodo.fr                         NaN
# 6                  harven@harven.es                 harvengroup
# 7   falcons@falconsdevilafranca.cat                  falconsvfp
# 8                info@destockage.es                         NaN
# 9     info@reciclajesdelsurbahia.es  reciclajesdelsurbahias.l.1
#
#                               phones     platform
# 0                   +34 658 50 13 65      Shopify
# 1  +34 916 26 38 18,+34 935 64 63 46  WooCommerce
# 2                   +34 633 53 95 00  WooCommerce
# 3                   +34 680 84 97 93  WooCommerce
# 4                   +34 661 01 73 17      Shopify
# 5  +34 925 25 88 72,+34 925 21 69 69      Shopify
# 6  +34 928 20 16 36,+34 928 20 35 22  WooCommerce
# 7                   +34 678 44 78 40          Wix
# 8                   +34 633 12 20 55         Odoo
# 9                   +34 956 40 62 00      BaseKit

# %%
#urls = ["https://bellascositas.es/","https://pikadura.es/es/"]
import time
# Record the start time
start_time = time.time()
##########
#Para hacerlo a traves de un excel y un dataframe
urls = list(df['domain'][:10])
#urls = ["Rebels108.com","www.ergonomika.es","Tiendascaprichos.com","Klix.es","www.hillsgarden.co","Lalaynina.com","Superfantasticas.com"]
new_url = []
for url in urls:
    url_nueva = 'https://'+url+'/'
    new_url.append(url_nueva)
print(new_url)


#url = ['https://www.powerbuildingoficial.com/']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 7
#       4 start_time = time.time()
#       5 ##########
#       6 #Para hacerlo a traves de un excel y un dataframe
# ----> 7 urls = list(df['domain'][:10])
#       8 #urls = ["Rebels108.com","www.ergonomika.es","Tiendascaprichos.com","Klix.es","www.hillsgarden.co","Lalaynina.com","Superfantasticas.com"]
#       9 new_url = []
#
# NameError: name 'df' is not defined

# %%
# !pip freeze
# Out:
# aiohttp==3.8.5
# aiosignal==1.3.1
# annotated-types==0.5.0
# anyio==3.7.1
# async-timeout==4.0.3
# attrs==23.1.0
# beautifulsoup4==4.12.2
# blis==0.7.10
# boltons @ file:///C:/ci_311/boltons_1677729932371/work
# brotlipy==0.7.0
# catalogue==2.0.9
# certifi @ file:///C:/b/abs_4a0polqwty/croot/certifi_1683875377622/work/certifi
# cffi @ file:///C:/ci_311/cffi_1676423759166/work
# charset-normalizer @ file:///tmp/build/80754af9/charset-normalizer_1630003229654/work
# click==8.1.7
# colorama @ file:///C:/ci_311/colorama_1676422310965/work
# conda @ file:///C:/b/abs_b5q92oum8h/croot/conda_1689272261421/work
# conda-content-trust @ file:///C:/ci_311/conda-content-trust_1676467587370/work
# conda-libmamba-solver @ file:///C:/b/abs_5a9xvt2a3k/croot/conda-libmamba-solver_1685032355900/work/src
# conda-package-handling @ file:///C:/b/abs_ce4_vcfd0y/croot/conda-package-handling_1685024800103/work
# conda_package_streaming @ file:///C:/b/abs_88a7k_wmm1/croot/conda-package-streaming_1685019697115/work
# confection==0.1.3
# cryptography @ file:///C:/b/abs_b28tzldafl/croot/cryptography_1686613103834/work
# cymem==2.0.8
# dill==0.3.7
# dnspython==2.4.2
# elastic-transport==8.4.0
# elasticsearch==8.9.0
# email-validator==2.0.0.post2
# faiss-cpu==1.7.4
# fastapi==0.103.1
# filelock==3.12.4
# frozenlist==1.4.0
# fsspec==2023.9.1
# greenlet==2.0.2
# h11==0.14.0
# httpcore==0.18.0
# httptools==0.6.0
# httpx==0.25.0
# huggingface-hub==0.17.1
# idna @ file:///C:/ci_311/idna_1676424932545/work
# itsdangerous==2.1.2
# Jinja2==3.1.2
# joblib==1.3.2
# jsonpatch @ file:///tmp/build/80754af9/jsonpatch_1615747632069/work
# jsonpointer==2.1
# langchain==0.0.39
# langcodes==3.3.0
# libmambapy @ file:///C:/b/abs_f0tnqlkcbn/croot/mamba-split_1685993165748/work/libmambapy
# manifest-ml==0.0.1
# MarkupSafe==2.1.3
# menuinst @ file:///C:/ci_311/menuinst_1678730372782/work
# multidict==6.0.4
# murmurhash==1.0.10
# nltk==3.8.1
# numpy==1.26.0
# openai==0.28.0
# orjson==3.9.7
# packaging @ file:///C:/b/abs_ed_kb9w6g4/croot/packaging_1678965418855/work
# pandas==2.1.0
# pathy==0.10.2
# pluggy @ file:///C:/ci_311/pluggy_1676422178143/work
# preshed==3.0.9
# pycosat @ file:///C:/ci_311/pycosat_1676438455539/work
# pycparser @ file:///tmp/build/80754af9/pycparser_1636541352034/work
# pydantic==2.0.3
# pydantic-extra-types==2.1.0
# pydantic-settings==2.0.3
# pydantic_core==2.3.0
# pyOpenSSL @ file:///C:/b/abs_de215ipd18/croot/pyopenssl_1678965319166/work
# PySocks @ file:///C:/ci_311/pysocks_1676425991111/work
# python-dateutil==2.8.2
# python-dotenv==1.0.0
# python-multipart==0.0.6
# pytz==2023.3.post1
# PyYAML==6.0.1
# redis==5.0.0
# regex==2023.8.8
# requests @ file:///C:/b/abs_41owkd5ymz/croot/requests_1682607524657/work
# ruamel.yaml @ file:///C:/ci_311/ruamel.yaml_1676439214109/work
# safetensors==0.3.3
# six @ file:///tmp/build/80754af9/six_1644875935023/work
# smart-open==6.4.0
# sniffio==1.3.0
# soupsieve==2.5
# spacy==3.6.1
# spacy-legacy==3.0.12
# spacy-loggers==1.0.5
# SQLAlchemy==1.4.49
# sqlitedict==2.1.0
# srsly==2.4.7
# starlette==0.27.0
# thinc==8.1.12
# tiktoken==0.5.1
# tokenizers==0.13.3
# toolz @ file:///C:/ci_311/toolz_1676431406517/work
# tqdm @ file:///C:/b/abs_f76j9hg7pv/croot/tqdm_1679561871187/work
# transformers==4.33.2
# typer==0.9.0
# typing_extensions==4.7.1
# tzdata==2023.3
# ujson==5.8.0
# urllib3 @ file:///C:/b/abs_889_loyqv4/croot/urllib3_1686163174463/work
# uvicorn==0.23.2
# wasabi==1.1.2
# watchfiles==0.20.0
# websockets==11.0.3
# wikipedia==1.4.0
# win-inet-pton @ file:///C:/ci_311/win_inet_pton_1676425458225/work
# yarl==1.9.2
# zstandard==0.19.0

# %%
paginas_html = html_loader(new_url)

# %%
resumenes = []
for html in paginas_html:
    x = html.page_content.replace('\t','')
    y = x.replace('\n',' ')
    resumenes.append(summarizer(y))

# %%
query = 'Quiero facturar lo antes posible 20.000€ más al mes, cual es el camino más rápido?'
respuestas = []
nichos = []
for resumen in resumenes:
    nichos.append(nicho_finder(resumen))
    respuestas.append(advisor(query,resumen))

# Record the end time
end_time = time.time()

# Calculate the elapsed time
elapsed_time = end_time - start_time

# Print the result in seconds
print(f"Execution time: {float(elapsed_time)/60} minutes")
# Out:
# Execution time: 12.977583988507588 minutes

# %%
df['summary'] = resumenes
df['niche'] = nichos
df['personalized_email'] = respuestas

# %%
nom = 'mini_excels/mini_excelsoutput_1.xlsx'
nombre = nom.split('/')[1]
output_writer(df,nombre)
# Out:
# Uploaded mini_excelsoutput_1.xlsx to S3 at s3://mini-excels/output/mini_excelsoutput_1.xlsx

# %%
def read_excel_s3(bucket_name,s3_key):
    s3 = boto3.client('s3', aws_access_key_id=aws_access_key_id, aws_secret_access_key=aws_secret_access_key)
    
    # Specify the S3 bucket name
    s3_bucket_name = 'mini-excels'
    
    
    s3_key = 'mini_excels/mini_excelsoutput_1.xlsx'
    
    # 'https://mini-excels.s3.eu-west-1.amazonaws.com/mini_excels/mini_excelsoutput_1.xlsx'
    
    # Read the Excel file from S3
    s3_response = s3.get_object(Bucket=s3_bucket_name, Key=s3_key)
    excel_data = s3_response['Body'].read()
    
    # You can now parse 'excel_data' using a library like pandas.
    return pd.read_excel(excel_data)

# %%
data1 = pd.read_excel(excel_data)
data2 = pd.read_excel(excel_data)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_6260\3117675077.py:1: FutureWarning: Passing bytes to 'read_excel' is deprecated and will be removed in a future version. To read from a byte string, wrap it in a `BytesIO` object.
#   data1 = pd.read_excel(excel_data)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_6260\3117675077.py:2: FutureWarning: Passing bytes to 'read_excel' is deprecated and will be removed in a future version. To read from a byte string, wrap it in a `BytesIO` object.
#   data2 = pd.read_excel(excel_data)

# %%
s3 = boto3.client('s3', aws_access_key_id=aws_access_key_id, aws_secret_access_key=aws_secret_access_key)

# Specify the S3 bucket name
s3_bucket_name = 'mini-excels'

# List of output Excel data and file names
output_data = [
    {'data': pd.DataFrame(data1), 'file_name': 'output_file1.xlsx'},
    {'data': pd.DataFrame(data2), 'file_name': 'output_file2.xlsx'},
    # Add more data and file names as needed
]

# Upload each output Excel file to S3
for item in output_data:
    data = item['data']
    file_name = item['file_name']
    
    with tempfile.NamedTemporaryFile(suffix='.xlsx', delete=False) as temp_excel_file:
        data.to_excel(temp_excel_file.name, index=False, engine='xlsxwriter')

    # Read the temporary file into a binary stream
    with open(temp_excel_file.name, 'rb') as temp_file:
        excel_bytes = io.BytesIO(temp_file.read())

    # Specify the S3 key (file path) for the output file
    s3_key = f'output/{file_name}'  # You can customize the path as needed

    # Upload the Excel data to S3
    s3.put_object(Bucket=s3_bucket_name, Key=s3_key, Body=excel_bytes)

    print(f'Uploaded {file_name} to S3 at s3://{s3_bucket_name}/{s3_key}')
# Out:
# Uploaded output_file1.xlsx to S3 at s3://mini-excels/output/output_file1.xlsx
# Uploaded output_file2.xlsx to S3 at s3://mini-excels/output/output_file2.xlsx

# %%
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_6260\3423066952.py:1: FutureWarning: Passing bytes to 'read_excel' is deprecated and will be removed in a future version. To read from a byte string, wrap it in a `BytesIO` object.
#   pd.read_excel(excel_data)
#                            domain country_code    created  \
# 0  www.visionnocturnaytermica.com       España 2023-05-19
# 1           www.gepcoformacion.es       España 2023-04-14
# 2                 mrribsmadrid.es       España 2023-05-19
# 3                         lewu.es       España 2023-04-07
# 4    www.powerbuildingoficial.com       España 2023-04-14
# 5                  electrotodo.fr       España 2023-04-07
# 6                   www.harven.es       España 2023-04-28
# 7     www.falconsdevilafranca.cat       España 2023-03-24
# 8               www.destockage.es       España 2023-06-02
# 9    www.reciclajesdelsurbahia.es       España 2023-04-21
#
#                              emails                   instagram  \
# 0   shop@visionnocturnaytermica.com   vision_nocturna_y_termica
# 1       info@gestionemergencias.com             gepco_formacion
# 2              info@mrribsmadrid.es              mr_ribs_madrid
# 3                      info@lewu.es     lewulearnandenjoywithus
# 4  soporte@powerbuildingoficial.com       powerbuilding_oficial
# 5           boutique@electrotodo.fr                         NaN
# 6                  harven@harven.es                 harvengroup
# 7   falcons@falconsdevilafranca.cat                  falconsvfp
# 8                info@destockage.es                         NaN
# 9     info@reciclajesdelsurbahia.es  reciclajesdelsurbahias.l.1
#
#                               phones     platform
# 0                   +34 658 50 13 65      Shopify
# 1  +34 916 26 38 18,+34 935 64 63 46  WooCommerce
# 2                   +34 633 53 95 00  WooCommerce
# 3                   +34 680 84 97 93  WooCommerce
# 4                   +34 661 01 73 17      Shopify
# 5  +34 925 25 88 72,+34 925 21 69 69      Shopify
# 6  +34 928 20 16 36,+34 928 20 35 22  WooCommerce
# 7                   +34 678 44 78 40          Wix
# 8                   +34 633 12 20 55         Odoo
# 9                   +34 956 40 62 00      BaseKit

# %% [markdown]
# ## Pruebas

# %%
df = pd.read_excel(r'C:\Users\Usuario\Desktop\FlaskProjects\Shopify_analizer\99 correctos.xlsx')

# %%
import time
# Record the start time
start_time = time.time()
##########
#Para hacerlo a traves de un excel y un dataframe
urls = list(df['domain'])
#urls = ["Rebels108.com","www.ergonomika.es","Tiendascaprichos.com","Klix.es","www.hillsgarden.co","Lalaynina.com","Superfantasticas.com"]
new_url = []
for url in urls:
    url_nueva = 'https://'+url
    new_url.append(url_nueva)
print(new_url)
# Out:
# ['https://www.visionnocturnaytermica.com', 'https://www.gepcoformacion.es', 'https://mrribsmadrid.es', 'https://lewu.es', 'https://www.powerbuildingoficial.com', 'https://electrotodo.fr', 'https://www.harven.es', 'https://www.falconsdevilafranca.cat', 'https://www.destockage.es', 'https://www.reciclajesdelsurbahia.es', 'https://store.kingsleague.pro', 'https://es.acebattery.com', 'https://es.ridex.eu', 'https://tienda.artser.es', 'https://market.noticiasgourmet.es', 'https://desarrollo.winegogh.es', 'https://shop.fander.es', 'https://tienda.villanueva.edu', 'https://da.roble.store', 'https://es.tripnbike.com', 'https://admin.bibloo.es', 'https://regala.pancracio.com', 'https://store.a-emotionallight.com', 'https://es.twobrothers-store.com', 'https://pt.ysabelmora.com', 'https://es.aeratron.io', 'https://es.ketocharge.com', 'https://es.watchesofamerica.com', 'https://de.boneandwhite.com', 'https://tienda.intech3d.es', 'https://ie.bouchrafilalilahlou.com', 'https://ibiza-blau-music.sumupstore.com', 'https://b2b.jyoko.com', 'https://es.neuromodus.com', 'https://ca.lifestylegarden.com', 'https://iberia-eshop.bego.com', 'https://es.opuradio.com', 'https://es.redpackdrums.com', 'https://it.cacaolaboratory.eu', 'https://es.montparel.com', 'https://es.parniswatch.com', 'https://es.mindfulcollective.co', 'https://es.syncwire.com', 'https://b2b.velcamotor.com', 'https://shop-us.corporissanum.com', 'https://admin.osmosys.eu', 'https://cdn1.bilsteinsuspension.com', 'https://tienda.estudioaequus.com', 'https://tienda.bonpilates.com', 'https://www.royalschoolofmusic.es', 'https://pitosyflautas.es', 'https://tienda.jb-vestuario.com', 'https://grupototapunt.com', 'https://www.naturalove.es', 'https://www.landoffreedom.eu', 'https://herrerafood.com', 'https://joopikids.es', 'https://noobe.es', 'https://www.wabisabiramenbar.es', 'https://fuenteplateada.es', 'https://www.ecosferas.com', 'https://joinbanana.es', 'https://desguacesbru.es', 'https://coacmto.com', 'https://estudio72.es', 'https://ceav.info', 'https://arabianoud.com.es', 'https://www.befarmacia.es', 'https://www.orquestasinfonicadetorrevieja.es', 'https://www.farmaciahilario.es', 'https://www.kankenami.eu', 'https://juegaespana.es', 'https://www.ajmalls.us', 'https://www.misscheevy.com', 'https://www.farmaciaayala53.es', 'https://kuril.es', 'https://royalgrass.es', 'https://www.g6padelgym.com', 'https://www.xn--missmejoresuas-1nb.es', 'https://casaomuino.com', 'https://mercadomunicipalsoria.es', 'https://hiperfincas.com', 'https://snowmancomforter.com', 'https://maitecardenas.com', 'https://nicolett.es', 'https://www.campingflorida.es', 'https://www.laromanicanarias.es', 'https://farmaciaedificioeuropa.es', 'https://cielitolindocafe.es', 'https://zahoribooks.com', 'https://www.kayzenemprende.es', 'https://www.farmaciaolgaasin.es', 'https://santoremedio.es', 'https://costaeste.es', 'https://urbansport.es', 'https://www.guillaumelemariefotografo.com', 'https://es.theiepadvocate.com', 'https://www.joylu.es', 'https://vivevendiendo.es']

# %%
from langchain.document_loaders import UnstructuredURLLoader

def url_loader(urls):
    loader = UnstructuredURLLoader(urls=urls)
    data = loader.load()
    return data

htmls = html_loader(new_url)

end_time = time.time()

# Calculate the elapsed time
elapsed_time = end_time - start_time

# Print the result in seconds
print(f"Execution time: {float(elapsed_time)/60} minutes")
# Out:
# Execution time: 4.646285100777944 minutes

# %%
len(htmls)
# Out:
# 99

# %%
textos = []
for html in htmls:
    x = html.page_content.replace('\t','')
    y = x.replace('\n',' ')
    textos.append(y)

# %%
df['paginas']= textos

# %%
df.to_excel(r'C:\Users\Usuario\Desktop\FlaskProjects\Shopify_analizer\99 correctos_paginas.xlsx')
